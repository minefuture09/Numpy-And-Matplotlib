# %%
import matplotlib.pyplot as plt 


activities = ['eat','sleep','work','play']


slices = [3,7,8,6]

color = ['r','g','b','m']

plt.pie(slices,labels=activities,colors = color,explode=(0.2,0,0,0),shadow = True,startangle=90,autopct = '%1.2f%%')
plt.legend()
plt.show()
